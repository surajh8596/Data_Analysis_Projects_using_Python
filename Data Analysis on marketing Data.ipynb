# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('D:\PGP IN DATA SCIENCE with Careerera\Data Sets\innomatics\marketing_data.csv')
df.head()
# Out:
#       ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
# 2         1     5/13/14        0       134  ...                  5
# 3         1     5/11/14        0        10  ...                  2
# 4         0      4/8/14        0         6  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.columns=df.columns.str.replace(" ", "")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df['Income']=df['Income'].str.strip('$')
df['Income']=df['Income'].str.replace(',','')
df['Income']
# Out:
# 0       84835.00
# 1       57091.00
# 2       67267.00
# 3       32474.00
# 4       21474.00
#           ...
# 2235    66476.00
# 2236    31056.00
# 2237    46310.00
# 2238    65819.00
# 2239    94871.00
# Name: Income, Length: 2240, dtype: object

# %%
df['Income']=df['Income'].astype('float')
df['Income'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Univariate analysis

# %% [markdown]
# ### Analyse Income

# %% [markdown]
# - Numerical type column, Categorical

# %%
df['Income'].mean()
# Out:
# 52247.25135379061

# %%
df['Income'].median()
# Out:
# 51381.5

# %%
df['Income'].std()
# Out:
# 25173.0766609014

# %%
df['Income'].max()
# Out:
# 666666.0

# %%
df['Income'].min()
# Out:
# 1730.0

# %%
df['Income'].plot(kind='hist', figsize=(18,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Income'].plot(kind='kde', figsize=(18,5))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Income'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
clean_df=df[df['Income']<200000]
clean_df['Income'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
clean_df['Income'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
clean_df['Income'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
print(df['Income'].mean())
print(clean_df['Income'].mean())
# Out:
# 52247.25135379061
# 51969.861399548536

# %%
print(df['Income'].median())
print(clean_df['Income'].median())
# Out:
# 51381.5
# 51373.0

# %%
print(df['Income'].std())
print(clean_df['Income'].std())
# Out:
# 25173.0766609014
# 21526.320094910978

# %% [markdown]
# Range

# %%
df['Income'].max()-df['Income'].min()
# Out:
# 664936.0

# %% [markdown]
# IQR

# %%
q1=df['Income'].quantile(0.25)
q3=df['Income'].quantile(0.75)

# %%
q1
# Out:
# 35303.0

# %%
q3
# Out:
# 68522.0

# %%
IQR=q3-q1

# %%
IQR
# Out:
# 33219.0

# %%
lower_bound=q1 - 1.5*IQR
upper_bound=q3 + 1.5*IQR

# %%
lower_bound
# Out:
# -14525.5

# %%
upper_bound
# Out:
# 118350.5

# %%
cleaned_df=df[(df['Income']<upper_bound) & (df['Income']>lower_bound)]

# %%
cleaned_df['Income'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
cleaned_df['Income'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
cleaned_df['Income'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Column is numeric type
# -- univariate- box, kde, dist, hist, statistical summary
# #### Column is categorical type
# -- univaiate- count, pie, mode

# %%
df['Income'].plot()
# Out:
# <AxesSubplot:>

# %%
df.dropna(inplace=True)

# %%
df['Education'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Marital_Status'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Marital_Status'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bivariate analysis
# - Checking the relationship between 2 columns
# - numeracal & numerical - scatter plot
# - numerical & categorical- box plot, barplot
# - categorical & categorical - stacked barchart, crosstabs

# %%
df['age']=2023-df['Year_Birth']
df.head()
# Out:
#       ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  NumWebVisitsMonth  AcceptedCmp3  \
# 0     6/16/14        0       189  ...                  1             0
# 1     6/15/14        0       464  ...                  5             0
# 2     5/13/14        0       134  ...                  2             0
# 3     5/11/14        0        10  ...                  7             0
# 4      4/8/14        0         6  ...                  7             1
#
#    AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Numerical vs Numerical

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(y='MntWines', x='Income', data=cleaned_df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='MntWines'>

# %%
cleaned_df['MntGoldProds'].mean()
# Out:
# 44.11096014492754

# %%
df['MntGoldProds'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(y='MntGoldProds', x='Income', data=cleaned_df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='MntGoldProds'>

# %%
+919309563980
# Out:
# 919309563980

# %% [markdown]
# ### Numerical vs Categorical

# %%
plt.figure(figsize=(12,5))
sns.boxplot(y='MntWines', x='Education', data=cleaned_df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='MntWines'>

# %%
sns.barplot(x='Country', y='Income', data=cleaned_df, ci=None)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Income'>

# %% [markdown]
# ### categorical & categorical - stacked barchart, crosstabs

# %%
pd.crosstab(index=df['Education'], columns=df['Country'])
# Out:
# Country     AUS   CA  GER  IND  ME   SA   SP  US
# Education
# 2n Cycle      8   24   19   20   0   25   97   7
# Basic         4    7    2    4   0    6   28   3
# Graduation   79  132   58   76   1  161  546  63
# Master       29   49   19   21   1   60  171  15
# PhD          27   54   18   26   1   85  251  19

# %%
df[df['Country']=='ME']
# Out:
#         ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 149   9323        1949      Master       Together  49912.0        0         1
# 293   5080        1993  Graduation         Single  70515.0        0         0
# 1436  2920        1975         PhD         Single  52614.0        0         1
#
#      Dt_Customer  Recency  MntWines  ...  NumWebVisitsMonth  AcceptedCmp3  \
# 149       9/7/12        5       520  ...                  8             1
# 293     10/21/13       12       420  ...                  2             0
# 1436     12/1/12       63       789  ...                  8             0
#
#       AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  \
# 149              0             0             0             0         1
# 293              0             0             0             0         1
# 1436             0             0             0             0         0
#
#       Complain  Country  age
# 149          0       ME   74
# ...

# %%
cleaned_df.boxplot(by='Education', column='MntWines', figsize=(12,8))
# Out:
# <AxesSubplot:title={'center':'MntWines'}, xlabel='Education'>

# %%
cleaned_df.boxplot(by='Education', column='Income', figsize=(12,8))
# Out:
# <AxesSubplot:title={'center':'Income'}, xlabel='Education'>

# %% [markdown]
# ### Multivariate analaysis

# %%
df.corr()
# Out:
#                            ID  Year_Birth    Income   Kidhome  Teenhome  \
# ID                   1.000000    0.002355  0.013095  0.001736 -0.003030
# Year_Birth           0.002355    1.000000 -0.161791  0.233615 -0.350791
# Income               0.013095   -0.161791  1.000000 -0.428669  0.019133
# Kidhome              0.001736    0.233615 -0.428669  1.000000 -0.039869
# Teenhome            -0.003030   -0.350791  0.019133 -0.039869  1.000000
# Recency             -0.044376   -0.016295 -0.003970  0.011492  0.013838
# MntWines            -0.021084   -0.159451  0.578650 -0.497336  0.003747
# MntFruits            0.007326   -0.017747  0.430842 -0.373396 -0.176558
# MntMeatProducts     -0.005902   -0.033697  0.584633 -0.439261 -0.261122
# MntFishProducts     -0.023992   -0.040425  0.438871 -0.388884 -0.205242
# MntSweetProducts    -0.005936   -0.020204  0.440744 -0.378026 -0.163056
# MntGoldProds        -0.011172   -0.064208  0.325916 -0.355029 -0.019887
# ...

# %% [markdown]
# ### Numerical

# %%
num_col=cleaned_df.select_dtypes(include=['int64','float64'])

# %%
num_col.columns
# Out:
# Index(['ID', 'Year_Birth', 'Income', 'Kidhome', 'Teenhome', 'Recency',
#        'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5',
#        'AcceptedCmp1', 'AcceptedCmp2', 'Response', 'Complain'],
#       dtype='object')

# %% [markdown]
# ### Categorical

# %%
cat_col=cleaned_df.select_dtypes(include='object')
cat_col.columns
# Out:
# Index(['Education', 'Marital_Status', 'Dt_Customer', 'Country'], dtype='object')

# %%
num_col=num_col.drop(['ID', 'Response', 'Complain','AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2'], axis=1)

# %%
len(num_col.columns)
# Out:
# 16

# %%
num_col.columns
# Out:
# Index(['Year_Birth', 'Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth'],
#       dtype='object')

# %%
num_col.plot(kind='kde', figsize=(20,10), subplots=True, layout=(4,5), sharex=False, sharey=False);

# %%
num_col.plot(kind='hist', figsize=(20,10), subplots=True, layout=(4,5), sharex=False, sharey=False);

# %%
num_col.plot(kind='box', figsize=(20,10), subplots=True, layout=(4,5), sharex=False, sharey=False);
