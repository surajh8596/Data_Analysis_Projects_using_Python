# %% [markdown]
# ![Untitledwe.png](attachment:Untitledwe.png)

# %% [markdown]
# ### What are your career aspirations?
# * Career aspirations refer to those long-term career goals, plans and dreams that are far away in the future rather than the short-term ones in the present.
# * Employers often ask about your future career aspirations to get to know you and understand your career goals and occupational aspirations.
# * Your occupational aspirations get to define your short-term career choices. In the process of your career development, your education and career choices should ideally reflect what you want your career to become in the longer term.

# %% [markdown]
# ### Import required library

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load & Read Dataset

# %%
pd.options.display.max_colwidth=1000000

# %%
df=pd.read_csv('D:\PGP IN DATA SCIENCE with Careerera\Data Sets\\career_aspiration.csv')
df.head()
# Out:
#   Your Current Country.  Your Current Zip Code / Pin Code Your Gender  \
# 0                 India                            273005        Male
# 1                 India                            851129        Male
# 2                 India                            123106      Female
# 3                 India                            834003        Male
# 4                 India                            301019      Female
#
#   Which of the below factors influence the most about your career aspirations ?  \
# 0                                  People who have changed the world for better
# 1                                  People who have changed the world for better
# 2                                                    Social Media like LinkedIn
# 3                                 People from my circle, but not family members
# 4                                        Influencers who had successful careers
#
# ...

# %%
df.shape
# Out:
# (235, 15)

# %%
df.size
# Out:
# 3525

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 15 columns):
#  #   Column                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                    --------------  -----
#  0   Your Current Country.                                                                                                     235 non-null    object
#  1   Your Current Zip Code / Pin Code                                                                                          235 non-null    int64
#  2   Your Gender                                                                                                               235 non-null    object
# ...

# %% [markdown]
# ### Missing Value

# %%
df.isna().sum()
# Out:
# Your Current Country.                                                                                                       0
# Your Current Zip Code / Pin Code                                                                                            0
# Your Gender                                                                                                                 0
# Which of the below factors influence the most about your career aspirations ?                                               0
# Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.    0
# How likely is that you will work for one employer for 3 years or more ?                                                     0
# Would you work for a company whose mission is not clearly defined and publicly posted.                                      0
# ...

# %% [markdown]
# No Missing values

# %% [markdown]
# ### How Many Country Aspirats are present in Dataset

# %%
country=df['Your Current Country.'].value_counts()
country
# Out:
# India                       231
# Germany                       2
# United Arab Emirates          1
# United States of America      1
# Name: Your Current Country., dtype: int64

# %%
labels=country.index
values=country.values

fig=px.pie(values=values,
          labels=labels, hover_name=labels, names=labels,
          title='Aspirants Native Country')
fig.show()
# Out:
# <div>                            <div id="64cb5b3b-ea31-4481-8478-fa6af797d4b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64cb5b3b-ea31-4481-8478-fa6af797d4b9")) {                    Plotly.newPlot(                        "64cb5b3b-ea31-4481-8478-fa6af797d4b9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"<b>%{hovertext}</b><br><br>label=%{label}<br>value=%{value}<extra></extra>","hovertext":["India","Germany","United Arab Emirates","United States of America"],"labels":["India","Germany","United Arab Emirates","United States of America"],"legendgroup":"","name":"","showlegend":true,"values":[231,2,1,1],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dconto
# ...

# %% [markdown]
# ![newplot%20%2833%29.png](attachment:newplot%20%2833%29.png)

# %% [markdown]
# **About 99% Aspirants are Indian.**

# %% [markdown]
# ### Count of Male & Female Aspirants

# %%
gender=df['Your Gender'].value_counts()
gender
# Out:
# Male      156
# Female     79
# Name: Your Gender, dtype: int64

# %%
labels=gender.index
values=gender.values

fig=px.pie(values=values,
          labels=labels, hover_name=labels, names=labels,
          title='Count Male & Female Aspirants')
fig.show()
# Out:
# <div>                            <div id="967e6b6f-d944-4eec-902e-04e360ca3d9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("967e6b6f-d944-4eec-902e-04e360ca3d9f")) {                    Plotly.newPlot(                        "967e6b6f-d944-4eec-902e-04e360ca3d9f",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"<b>%{hovertext}</b><br><br>label=%{label}<br>value=%{value}<extra></extra>","hovertext":["Male","Female"],"labels":["Male","Female"],"legendgroup":"","name":"","showlegend":true,"values":[156,79],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[
# ...

# %% [markdown]
# ![newplot%20%2837%29.png](attachment:newplot%20%2837%29.png)

# %% [markdown]
# **66.4% Candidates are Male & 33.6% Candidates are Female.**

# %% [markdown]
# ### Lets Understand Each Questions in Detail.

# %% [markdown]
# ### Question-1
# #### Which of the below factors influence the most about your career aspirations ?

# %%
que1 = df["Which of the below factors influence the most about your career aspirations ?"].value_counts()
que1
# Out:
# My Parents                                       79
# People who have changed the world for better     57
# People from my circle, but not family members    39
# Influencers who had successful careers           37
# Social Media like LinkedIn                       23
# Name: Which of the below factors influence the most about your career aspirations ?, dtype: int64

# %%
index = que1.index
values = que1.values
fig = go.Figure(data=[go.Pie(labels=index, values=values)])
fig.update_layout(title_text='Factors That Influencing career Aspiration')
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=30,
                  marker=dict(line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="0cc41cd0-ee11-4c7a-bb02-28cb756f0da6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cc41cd0-ee11-4c7a-bb02-28cb756f0da6")) {                    Plotly.newPlot(                        "0cc41cd0-ee11-4c7a-bb02-28cb756f0da6",                        [{"labels":["My Parents","People who have changed the world for better","People from my circle, but not family members","Influencers who had successful careers","Social Media like LinkedIn"],"values":[79,57,39,37,23],"type":"pie","textfont":{"size":30},"marker":{"line":{"color":"black","width":3}},"hoverinfo":"label+value","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidt
# ...

# %% [markdown]
# ![newplot%20%2838%29.png](attachment:newplot%20%2838%29.png)

# %% [markdown]
# **Most of the Aspirants think that "Their Parents" are the Influencing Factor.**

# %% [markdown]
# ### Question-2
# #### Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it?

# %%
question= "Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it."
que2=df[question].value_counts()
que2
# Out:
# Yes, I will earn and do that                                    110
# No I would not be pursuing Higher Education outside of India     65
# No, But if someone could bare the cost I will                    60
# Name: Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it., dtype: int64

# %%
index = que2.index
values = que2.values
fig = go.Figure(data=[go.Pie(labels=index, values=values)])
fig.update_layout(title_text='Would you pursue a Higher Education outside of India with self sponsored Money')
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=30,
                  marker=dict(line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="7931a7f5-5c61-4d5f-b84a-f67995c36995" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7931a7f5-5c61-4d5f-b84a-f67995c36995")) {                    Plotly.newPlot(                        "7931a7f5-5c61-4d5f-b84a-f67995c36995",                        [{"labels":["Yes, I will earn and do that","No I would not be pursuing Higher Education outside of India","No, But if someone could bare the cost I will"],"values":[110,65,60],"type":"pie","textfont":{"size":30},"marker":{"line":{"color":"black","width":3}},"hoverinfo":"label+value","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0
# ...

# %% [markdown]
# ![newplot%20%2839%29.png](attachment:newplot%20%2839%29.png)

# %% [markdown]
# **46.8% Aspirants are Ready to go to abroad and pursue Higher Education, 25.5% are willing to go abroad if somwone help them, & 27.7% are not ready to go abroad for higher Education.**

# %% [markdown]
# ### Question-3
# #### How likely is that you will work for one employer for 3 years or more ?

# %%
que= "How likely is that you will work for one employer for 3 years or more ?"
que3= df[que].value_counts()
que3
# Out:
# This will be hard to do, but if it is the right company I would try    139
# Will work for 3 years or more                                           79
# No way, 3 years with one employer is crazy                              17
# Name: How likely is that you will work for one employer for 3 years or more ?, dtype: int64

# %%
index = que3.index
values = que3.values
fig = go.Figure(data=[go.Pie(labels=index, values=values)])
fig.update_layout(title_text='How likely is that you will work for one employer for 3 years or more ?')
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=30,
                  marker=dict(line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="769ccbac-28e7-41ec-a608-47e858549d7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("769ccbac-28e7-41ec-a608-47e858549d7a")) {                    Plotly.newPlot(                        "769ccbac-28e7-41ec-a608-47e858549d7a",                        [{"labels":["This will be hard to do, but if it is the right company I would try","Will work for 3 years or more","No way, 3 years with one employer is crazy"],"values":[139,79,17],"type":"pie","textfont":{"size":30},"marker":{"line":{"color":"black","width":3}},"hoverinfo":"label+value","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,
# ...

# %% [markdown]
# ![newplot%20%2840%29.png](attachment:newplot%20%2840%29.png)

# %% [markdown]
# **33.6% Aspirants are ready to Work for 3 years or more same Empployer/Company, 7.23 are Not ready and 59.1% are ready to work with that compnay if that company is right place to work.**

# %% [markdown]
# ### Question-4
# #### Would you work for a company whose mission is not clearly defined and publicly posted.

# %%
que= "Would you work for a company whose mission is not clearly defined and publicly posted."
que4= df[que].value_counts()
que4
# Out:
# No     157
# Yes     78
# Name: Would you work for a company whose mission is not clearly defined and publicly posted., dtype: int64

# %%
index = que4.index
values = que4.values
fig = go.Figure(data=[go.Pie(labels=index, values=values)])
fig.update_layout(title_text='Would you work for a company whose mission is not clearly defined and publicly posted.')
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=30,
                  marker=dict(line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="094bcad4-7a99-47d5-8da3-186b39b4676e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("094bcad4-7a99-47d5-8da3-186b39b4676e")) {                    Plotly.newPlot(                        "094bcad4-7a99-47d5-8da3-186b39b4676e",                        [{"labels":["No","Yes"],"values":[157,78],"type":"pie","textfont":{"size":30},"marker":{"line":{"color":"black","width":3}},"hoverinfo":"label+value","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5
# ...

# %% [markdown]
# ![newplot%20%2841%29.png](attachment:newplot%20%2841%29.png)

# %% [markdown]
# **It is Obvious the more Aspirants will say NO if the if the companies mission is not clearly defined as per advertized, Hence 66.8% said No & 33.2% Said Yes.**

# %% [markdown]
# ### Question-5
# #### How likely would you work for a company whose mission is misaligned with their public actions or even their product ?

# %%
que= "How likely would you work for a company whose mission is misaligned with their public actions or even their product ?"
que5= df[que].value_counts()
que5
# Out:
# Will NOT work for them    158
# Will work for them         77
# Name: How likely would you work for a company whose mission is misaligned with their public actions or even their product ?, dtype: int64

# %%
index = que5.index
values = que5.values
fig = go.Figure(data=[go.Pie(labels=index, values=values)])
fig.update_layout(title_text='How likely would you work for a company whose mission is misaligned with their public actions, their product ?')
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=30,
                  marker=dict(line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="f6131a62-9d6b-4a4f-84e0-40bb5db55d2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6131a62-9d6b-4a4f-84e0-40bb5db55d2b")) {                    Plotly.newPlot(                        "f6131a62-9d6b-4a4f-84e0-40bb5db55d2b",                        [{"labels":["Will NOT work for them","Will work for them"],"values":[158,77],"type":"pie","textfont":{"size":30},"marker":{"line":{"color":"black","width":3}},"hoverinfo":"label+value","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],
# ...

# %% [markdown]
# ![newplot%20%2842%29.png](attachment:newplot%20%2842%29.png)

# %% [markdown]
# **67.2% Aspirants Said "NO" & 32.8% Said "Yes" they will work for them if a company whose mission is misaligned with their public actions, their product.**

# %% [markdown]
# ### Question-6
# #### How likely would you work for a company whose mission is not bringing social impact ?

# %%
que= "How likely would you work for a company whose mission is not bringing social impact ?"
que6= df[que].value_counts()
que6
# Out:
# 5     49
# 8     34
# 7     31
# 6     26
# 1     25
# 3     19
# 4     18
# 2     16
# 10    10
# 9      7
# Name: How likely would you work for a company whose mission is not bringing social impact ?, dtype: int64

# %%
index = que6.index
values = que6.values
fig = go.Figure(data=[go.Pie(labels=index, values=values)])
fig.update_layout(title_text='How likely would you work for a company whose mission is not bringing social impact ?')
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=30,
                  marker=dict(line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="d67b5e93-239d-4585-bc1e-8f064168bf14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d67b5e93-239d-4585-bc1e-8f064168bf14")) {                    Plotly.newPlot(                        "d67b5e93-239d-4585-bc1e-8f064168bf14",                        [{"labels":[5,8,7,6,1,3,4,2,10,9],"values":[49,34,31,26,25,19,18,16,10,7],"type":"pie","textfont":{"size":30},"marker":{"line":{"color":"black","width":3}},"hoverinfo":"label+value","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.
# ...

# %% [markdown]
# ![newplot%20%2843%29.png](attachment:newplot%20%2843%29.png)

# %% [markdown]
# **Most people are happy working with a company whose mission is not to bring any social impact.**

# %% [markdown]
# ### Question-7
# #### What is the most preferred working environment for you.

# %%
que= "What is the most preferred working environment for you."
que7= df[que].value_counts()
que7
# Out:
# Fully Remote with Options to travel as and when needed                 60
# Hybrid Working Environment with less than 15 days a month at office    57
# Every Day Office Environment                                           50
# Hybrid Working Environment with less than 10 days a month at office    31
# Hybrid Working Environment with less than 3 days a month at office     26
# Fully Remote with No option to visit offices                           11
# Name: What is the most preferred working environment for you., dtype: int64

# %%
index = que7.index
values = que7.values
fig = go.Figure(data=[go.Pie(labels=index, values=values)])
fig.update_layout(title_text='What is the most preferred working environment for you.')
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=30,
                  marker=dict(line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="358064ba-9cf7-420f-aa1f-360923bafe7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("358064ba-9cf7-420f-aa1f-360923bafe7b")) {                    Plotly.newPlot(                        "358064ba-9cf7-420f-aa1f-360923bafe7b",                        [{"labels":["Fully Remote with Options to travel as and when needed","Hybrid Working Environment with less than 15 days a month at office","Every Day Office Environment","Hybrid Working Environment with less than 10 days a month at office","Hybrid Working Environment with less than 3 days a month at office","Fully Remote with No option to visit offices"],"values":[60,57,50,31,26,11],"type":"pie","textfont":{"size":30},"marker":{"line":{"color":"black","width":3}},
# ...

# %% [markdown]
# ![newplot%20%2844%29.png](attachment:newplot%20%2844%29.png)

# %% [markdown]
# - **1. 25.5% are Preffer "Fully Remote With option to travel when needed.**
# - **2. 24.3% are Preffer Hybrid Workink environment with less than 15 days a month at office.**
# - **3. 21.3% are preffer Every day Office Environment.**

# %% [markdown]
# ### Question-8
# #### Which of the below Employers would you work with.

# %%
que= "Which of the below Employers would you work with."
que8= df[que].value_counts()
que8
# Out:
# Employer who pushes your limits by enabling an learning environment, and rewards you at the end    113
# Employer who appreciates learning and enables that environment                                      75
# Employer who rewards learning and enables that environment                                          36
# Employer who pushes your limits and doesn't enables learning environment and never rewards you       7
# Employers who appreciates learning but doesn't enables an learning environment                       4
# Name: Which of the below Employers would you work with., dtype: int64

# %%
index = que8.index
values = que8.values
fig = go.Figure(data=[go.Pie(labels=index, values=values)])
fig.update_layout(title_text='Which of the below Employers would you work with.')
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=30,
                  marker=dict(line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="66cf4697-15f7-472d-8e6a-6f57a76ddef5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66cf4697-15f7-472d-8e6a-6f57a76ddef5")) {                    Plotly.newPlot(                        "66cf4697-15f7-472d-8e6a-6f57a76ddef5",                        [{"labels":["Employer who pushes your limits by enabling an learning environment, and rewards you at the end","Employer who appreciates learning and enables that environment","Employer who rewards learning and enables that environment","Employer who pushes your limits and doesn't enables learning environment and never rewards you","Employers who appreciates learning but doesn't enables an learning environment"],"values":[113,75,36,7,4],"type":"pie","textfont":{"si
# ...

# %% [markdown]
# ![newplot%20%2845%29.png](attachment:newplot%20%2845%29.png)

# %% [markdown]
# **Around 50% aspirants chose working with Employer who pushes your limits by enabling an learning environment, and rewards you at the end.**

# %% [markdown]
# ### Question-9
# #### Which type of learning environment that you are most likely to work in ?

# %%
que= "Which type of learning environment that you are most likely to work in ?"
que9= df[que].value_counts()
que9
# Out:
# Self Paced Learning Portals, Instructor or Expert Learning Programs                                  59
# Instructor or Expert Learning Programs, Trial and error by doing side projects within the company    45
# Instructor or Expert Learning Programs, Learning by observing others                                 41
# Self Paced Learning Portals, Learning by observing others                                            38
# Learning by observing others, Trial and error by doing side projects within the company              29
# Self Paced Learning Portals, Trial and error by doing side projects within the company               23
# Name: Which type of learning environment that you are most likely to work in ?, dtype: int64

# %%
index = que9.index
values = que9.values
fig = go.Figure(data=[go.Pie(labels=index, values=values)])
fig.update_layout(title_text='Which type of learning environment that you are most likely to work in ?')
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=30,
                  marker=dict(line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="ef42088f-5dcf-4319-a6dd-28937d9c3fa8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef42088f-5dcf-4319-a6dd-28937d9c3fa8")) {                    Plotly.newPlot(                        "ef42088f-5dcf-4319-a6dd-28937d9c3fa8",                        [{"labels":["Self Paced Learning Portals, Instructor or Expert Learning Programs","Instructor or Expert Learning Programs, Trial and error by doing side projects within the company","Instructor or Expert Learning Programs, Learning by observing others","Self Paced Learning Portals, Learning by observing others","Learning by observing others, Trial and error by doing side projects within the company","Self Paced Learning Portals, Trial and error by doing side proje
# ...

# %% [markdown]
# ![newplot%20%2846%29.png](attachment:newplot%20%2846%29.png)

# %% [markdown]
# - **25.1% Preffer Self Paced Learning Portals, Instructor or Expert Learning Programs.**
# - **19.1% Preffer Instructor or Expert Learning Programs, Trial and error by doing side projects within the company.**
# - **17.4% Preffer Instructor or Expert Learning Programs, Learning by observing others.**
# - **16.2% Preffer Self Paced Learning Portals, Learning by observing others.**
# - **12.3% Preffer Learning by observing others, Trial and error by doing side projects within the company.**
# - **9.79% Preffer Self Paced Learning Portals, Trial and error by doing side projects within the company.**

# %% [markdown]
# ### Question-10
# #### What type of Manager would you work without looking into your watch ?

# %%
que= "What type of Manager would you work without looking into your watch ?"
que10= df[que].value_counts()
que10
# Out:
# Manager who explains what is expected, sets a goal and helps achieve it    129
# Manager who clearly describes what she/he needs                             45
# Manager who sets goal and helps me achieve it                               37
# Manager who sets targets and expects me to achieve it                       21
# Manager who sets unrealistic targets                                         3
# Name: What type of Manager would you work without looking into your watch ?, dtype: int64

# %%
index = que10.index
values = que10.values
fig = go.Figure(data=[go.Pie(labels=index, values=values)])
fig.update_layout(title_text='What type of Manager would you work without looking into your watch ?')
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=30,
                  marker=dict(line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="f81c56c1-4cd4-460c-afa3-d32a1d78d482" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f81c56c1-4cd4-460c-afa3-d32a1d78d482")) {                    Plotly.newPlot(                        "f81c56c1-4cd4-460c-afa3-d32a1d78d482",                        [{"labels":["Manager who explains what is expected, sets a goal and helps achieve it","Manager who clearly describes what she/he needs","Manager who sets goal and helps me achieve it","Manager who sets targets and expects me to achieve it","Manager who sets unrealistic targets"],"values":[129,45,37,21,3],"type":"pie","textfont":{"size":30},"marker":{"line":{"color":"black","width":3}},"hoverinfo":"label+value","textinfo":"percent"}],                        {"templ
# ...

# %% [markdown]
# ![newplot%20%2847%29.png](attachment:newplot%20%2847%29.png)

# %% [markdown]
# **55% Aspirants would like to work under Manager who explains what is expected, sets a goal and helps achieve it.**

# %% [markdown]
# ### Conclusion:
# 1. **Most of the Aspirants think that "Their Parents" are the Influencing Factor.**
# 2. **Most Aspirants are Ready to go to abroad and pursue Higher Education**
# 3. **Most Apirants are ready to work with that compnay if that company is right place to work.**
# 4. **Most Aspirants said NO if the companies mission is not clearly defined as per advertized**
# 5. **Most Aspirants said that they will not work for them if a company whose mission is misaligned with their public actions, their product.**
# 6. **Most people are happy working with a company whose mission is not to bring any social impact.**
# 7. **Most Aspirants Preffer "Fully Remote With option to travel when needed.**
# 8. **Most aspirants chose working with Employer who pushes your limits by enabling an learning environment, and rewards you at the end**
# 9. **Most Aspirants Preffered Self Paced Learning Portals, Instructor or Expert Learning Programs**
# 10. **Most Aspirants would like to work under Manager who explains what is expected, sets a goal and helps achieve it.**
