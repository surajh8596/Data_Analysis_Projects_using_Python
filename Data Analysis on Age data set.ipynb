# %% [markdown]
# ![maxresdefault.jpg](attachment:maxresdefault.jpg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df=pd.read_csv('D:\\PGP IN DATA SCIENCE with Careerera\\Files\\AgeDataset.csv')
df
# Out:
#                 Id                     Name  \
# 0              Q23        George Washington
# 1              Q42            Douglas Adams
# 2              Q91          Abraham Lincoln
# 3             Q254  Wolfgang Amadeus Mozart
# 4             Q255     Ludwig van Beethoven
# ...            ...                      ...
# 1223004  Q77247326    Marie-Fortunée Besson
# 1223005  Q77249504              Ron Thorsen
# 1223006  Q77249818       Diether Todenhagen
# 1223007  Q77253909  Reginald Oswald Pearson
# 1223008  Q77254864             Horst Lerche
#
#                                          Short description Gender  \
# 0           1st president of the United States (1732–1799)   Male
# 1                              English writer and humorist   Male
# 2          16th president of the United States (1809-1865)   Male
# 3                Austrian composer of the Classical period   Male
# 4                   German classical and romantic composer   Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1223009 entries, 0 to 1223008
# Data columns (total 10 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Id                 1223009 non-null  object
#  1   Name               1223009 non-null  object
#  2   Short description  1155109 non-null  object
#  3   Gender             1089363 non-null  object
#  4   Country            887500 non-null   object
#  5   Occupation         1016095 non-null  object
#  6   Birth year         1223009 non-null  int64
#  7   Death year         1223008 non-null  float64
#  8   Manner of death    53603 non-null    object
#  9   Age of death       1223008 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 93.3+ MB

# %%
df.isnull().sum()
# Out:
# Id                         0
# Name                       0
# Short description      67900
# Gender                133646
# Country               335509
# Occupation            206914
# Birth year                 0
# Death year                 1
# Manner of death      1169406
# Age of death               1
# dtype: int64

# %%
df['Manner of death'].nunique()
# Out:
# 206

# %%
df['Manner of death'].value_counts().sort_values(ascending=False)
# Out:
# natural causes        33532
# suicide                5814
# accident               5044
# homicide               4692
# capital punishment     3415
#                       ...
# cold case                 1
# homicide; shooting        1
# lymphoma                  1
# aortic aneurysm           1
# stomach cancer            1
# Name: Manner of death, Length: 206, dtype: int64

# %%
df['Manner of death'].fillna('natural causes', inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                        0
# Name                      0
# Short description     67900
# Gender               133646
# Country              335509
# Occupation           206914
# Birth year                0
# Death year                1
# Manner of death           0
# Age of death              1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                 Id                     Name  \
# 0              Q23        George Washington
# 1              Q42            Douglas Adams
# 2              Q91          Abraham Lincoln
# 3             Q254  Wolfgang Amadeus Mozart
# 4             Q255     Ludwig van Beethoven
# ...            ...                      ...
# 1222992  Q77115074             Wim de Vreng
# 1222993  Q77121585            James Smillie
# 1223000  Q77218559             Gustav Siber
# 1223007  Q77253909  Reginald Oswald Pearson
# 1223008  Q77254864             Horst Lerche
#
#                                          Short description Gender  \
# 0           1st president of the United States (1732–1799)   Male
# 1                              English writer and humorist   Male
# 2          16th president of the United States (1809-1865)   Male
# 3                Austrian composer of the Classical period   Male
# 4                   German classical and romantic composer   Male
# ...

# %%
df['Birth year'].nunique()
# Out:
# 1887

# %%
df.Country.nunique()
# Out:
# 5505

# %%
df['Death year'].nunique()
# Out:
# 1928

# %%
df['Death year'].max()
# Out:
# 2021.0

# %%
df['Birth year'].max()
# Out:
# 2003

# %%
df['Death year'].min()
# Out:
# -2200.0

# %%
df['Birth year'].min()
# Out:
# -2284

# %%
df['Age of death'].max()
# Out:
# 122.0

# %%
df['Age of death'].min()
# Out:
# 11.0

# %% [markdown]
# ## who lived long?

# %%
pd.pivot_table(df, index='Age of death', values=None, aggfunc=max).sort_values(by='Age of death', ascending=False)
# Out:
#               Birth year              Country  Death year  Gender       Id  \
# Age of death
# 122.0               1875               France      1997.0  Female  Q182260
# 121.0               1865                Japan      1986.0    Male  Q435743
# 99.0                1922               Zambia      2021.0    Male  Q998192
# 98.0                1923         ancient Rome      2021.0    Male  Q997095
# 97.0                1924         ancient Rome      2021.0    Male   Q99467
# ...                  ...                  ...         ...     ...      ...
# 15.0                2003         ancient Rome      2018.0    Male   Q96990
# 14.0                2002  Western Han Dynasty      2016.0    Male  Q984401
# 13.0                2000         ancient Rome      2013.0    Male   Q99592
# 12.0                2001         ancient Rome      2013.0    Male   Q95643
# 11.0                2000         ancient Rome      2011.0    Male   Q99161
#
# ...

# %% [markdown]
# ## in which year most people are born?

# %%
df['Birth year'].value_counts().sort_values(ascending=False)
# Out:
#  1921    8822
#  1920    8808
#  1924    8493
#  1922    8478
#  1925    8472
#          ...
#  509        1
#  716        1
# -110        1
#  249        1
#  2003       1
# Name: Birth year, Length: 1887, dtype: int64

# %%
sns.countplot(x='Birth year', data=df,
             order=df['Birth year'].value_counts().sort_values(ascending=False)[:10].index);

# %% [markdown]
# ## in which year most people are died?

# %%
df['Death year'].value_counts().sort_values(ascending=False)
# Out:
#  2015.0    10182
#  2016.0     9963
#  2014.0     9958
#  2017.0     9705
#  2013.0     9672
#            ...
#  477.0         1
#  272.0         1
# -77.0          1
# -1220.0        1
#  944.0         1
# Name: Death year, Length: 1928, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Male                                              659548
# Female                                             73286
# Transgender Female                                    57
# Transgender Male                                      30
# Eunuch; Male                                          13
# Intersex                                               7
# Female; Male                                           5
# Transgender Male; Female                               3
# Non-Binary                                             2
# Female; Female                                         1
# Transgender Female; Intersex                           1
# Eunuch                                                 1
# Transgender Male; Male                                 1
# Transgender Female; Female                             1
# Intersex; Transgender Male                             1
# Transgender Female; Male                               1
# ...

# %%
sns.countplot(y='Gender', data=df);

# %%
df.Occupation.value_counts()
# Out:
# Artist                                                     207322
# Politician                                                 152916
# Athlete                                                     92645
# Researcher                                                  63799
# Military personnel                                          36025
#                                                             ...
# Ballet dancer; choreographer; french resistance fighter         1
# Master craftsman; chair-maker; furniture designer               1
# Stevedore; civil libertarianism                                 1
# Mountaineer; paraglider pilot                                   1
# Director; scout leader                                          1
# Name: Occupation, Length: 7750, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(y='Occupation', data=df,
             order=df.Occupation.value_counts().sort_values(ascending=False)[:10].index);

# %%
df.Gender = np.where(df.Gender.str.contains('Transgender', case=False),'Transgender',df['Gender'])
df.Gender = np.where(df.Gender.str.contains('Intersex', case=False),'Transgender',df['Gender'])
df.Gender = np.where(df.Gender.str.contains('Eunuch', case=False),'Transgender',df['Gender'])
df.Gender = np.where(df.Gender.str.contains('Binary', case=False),'Transgender',df['Gender'])
df.Gender = np.where(df.Gender.str.contains('Male',),'Male',df['Gender'])
df.Gender = np.where(df.Gender.str.contains('Female', case=False),'Female',df['Gender'])

df.Gender.value_counts(dropna=False)
# Out:
# Male           659553
# Female          73287
# Transgender       121
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(y='Occupation', data=df, hue='Gender',
             order=df.Occupation.value_counts().sort_values(ascending=False)[:10].index);

# %%
df['century'] = df['Death year'] // 100 + 1
df['century'].value_counts()
# Out:
#  20.0    400472
#  21.0    181107
#  19.0    100626
#  18.0     21912
#  17.0     14004
#  16.0      6552
#  15.0      2109
#  14.0      1465
#  13.0      1208
#  12.0       874
#  11.0       491
#  10.0       352
#  9.0        298
#  8.0        281
#  3.0        254
#  7.0        229
#  4.0        141
#  6.0        122
#  5.0        105
#  2.0         90
# -1.0         60
#  0.0         59
#  1.0         39
# -2.0         39
# -3.0         31
# -4.0         21
# -11.0         7
# -15.0         2
# -6.0          2
# -12.0         2
# -5.0          2
# -14.0         1
# -21.0         1
# -10.0         1
# -7.0          1
# -16.0         1
# Name: century, dtype: int64

# %%
df.groupby('century').agg({'Age of death' : 'mean'}).plot();

# %%
df['Manner of death'].unique()
# Out:
# array(['natural causes', 'homicide', 'suicide', 'accident',
#        'capital punishment', 'death in battle', 'unnatural death',
#        'extrajudicial killing', 'capital punishment; suicide',
#        'homicide; natural causes', 'capital punishment; homicide',
#        'euthanasia', 'suicide; natural causes',
#        'capital punishment; unnatural death', 'epilepsy', 'complication',
#        'summary execution', 'suicide; accident',
#        'suicide; homicide; accident', 'suicide; homicide; natural causes',
#        'suicide; unfortunate accident', 'gunshot', 'internal bleeding',
#        'cardiac arrest; natural causes', 'accident; natural causes',
#        'Pospíšil', 'Category:People executed by firing squad', 'era',
#        'homicide; regicide', 'capital punishment; torture',
#        'maternal death', 'strain', 'Eastern Front of World War II',
#        'sleep apnea', 'suicide attack', 'lynching', 'schizophrenia',
# ...

# %%
df1=df[df['Manner of death']=='natural causes']
df1
# Out:
#                 Id                       Name  \
# 0              Q23          George Washington
# 1              Q42              Douglas Adams
# 3             Q254    Wolfgang Amadeus Mozart
# 4             Q255       Ludwig van Beethoven
# 5             Q260  Jean-François Champollion
# ...            ...                        ...
# 1222992  Q77115074               Wim de Vreng
# 1222993  Q77121585              James Smillie
# 1223000  Q77218559               Gustav Siber
# 1223007  Q77253909    Reginald Oswald Pearson
# 1223008  Q77254864               Horst Lerche
#
#                                          Short description Gender  \
# 0           1st president of the United States (1732–1799)   Male
# 1                              English writer and humorist   Male
# 3                Austrian composer of the Classical period   Male
# 4                   German classical and romantic composer   Male
# 5                                 French classical scholar   Male
# ...

# %%
df2=df[df['Manner of death']=='suicide']
df2
# Out:
#                 Id                      Name  \
# 14            Q352              Adolf Hitler
# 23            Q440          Salvador Allende
# 45            Q635                 Cleopatra
# 131          Q1322     José Manuel Balmaceda
# 189          Q2022             Cesare Pavese
# ...            ...                       ...
# 1210240  Q68639007             Kemény György
# 1213739  Q73375287             Peter Kuranda
# 1214539  Q75135015        Michael Benveniste
# 1215398  Q75336010  George Dewey Sanford Jr.
# 1215502  Q75349931               John Saxton
#
#                                          Short description  Gender  \
# 14       Austrian-born German politician, chancellor an...    Male
# 23                     28th president of Chile (1908–1973)    Male
# 45                  last active pharaoh of Ptolemaic Egypt  Female
# 131           Chilean politician and President (1840-1891)    Male
# 189      Italian poet, novelist, literary critic, and t...    Male
# ...

# %%
df3=df[df['Manner of death']=='accident']
df3
# Out:
#                 Id                       Name  \
# 20            Q407             Linda Lovelace
# 32            Q504                 Émile Zola
# 78            Q926             Roald Amundsen
# 94           Q1056                Italo Balbo
# 115          Q1257      Boutros Boutros-Ghali
# ...            ...                        ...
# 1203776  Q65148915         Ekaterina Koroleva
# 1206015  Q65967132  Stephen 'Cajun' Del Bagno
# 1208711  Q67171861           Kylie Rae Harris
# 1210058  Q68228066          Gerald W. Farrier
# 1212233  Q71262658                Patrick Day
#
#                                          Short description  Gender  \
# 20       American pornographic actress, later anti-porn...  Female
# 32                                           French writer    Male
# 78       Norwegian explorer; first person to reach the ...    Male
# 94       Italian Marshal of the Air Force and minister ...    Male
# 115      6th Secretary-General of the United Nations (1...    Male
# ...

# %% [markdown]
# ## suicide deaths in every century

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='century', data=df2);

# %% [markdown]
# ## accident deaths in every century

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='century', data=df3);

# %% [markdown]
# ## natural deaths in every century

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='century', data=df1);
