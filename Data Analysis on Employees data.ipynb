# %% [markdown]
# ## Employees Data Analysis
# ![people-image.jpg](attachment:people-image.jpg)

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('D:\\PGP IN DATA SCIENCE with Careerera\\Files\\employees_data.csv')
df
# Out:
#      employee_id    job_id  manager_id  department_id  location_id country_id  \
# 0            145    SA_MAN       100.0             80         2500         UK
# 1            146    SA_MAN       100.0             80         2500         UK
# 2            147    SA_MAN       100.0             80         2500         UK
# 3            148    SA_MAN       100.0             80         2500         UK
# 4            149    SA_MAN       100.0             80         2500         UK
# ..           ...       ...         ...            ...          ...        ...
# 101          118  PU_CLERK       114.0             30         1700         US
# 102          119  PU_CLERK       114.0             30         1700         US
# 103          201    MK_MAN       100.0             20         1800         CA
# 104          202    MK_REP       201.0             20         1800         CA
# 105          200   AD_ASST       101.0             10         1700         US
#
# ...

# %%
df.shape
# Out:
# (106, 16)

# %% [markdown]
# ## how  many non-null values present in each column?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_id      106 non-null    int64
#  1   job_id           106 non-null    object
#  2   manager_id       105 non-null    float64
#  3   department_id    106 non-null    int64
#  4   location_id      106 non-null    int64
#  5   country_id       106 non-null    object
#  6   first_name       106 non-null    object
#  7   last_name        106 non-null    object
#  8   salary           106 non-null    float64
#  9   commission_pct   34 non-null     float64
#  10  department_name  106 non-null    object
#  11  job_title        106 non-null    object
#  12  city             106 non-null    object
#  13  state_province   105 non-null    object
#  14  country_name     106 non-null    object
#  15  region_name      106 non-null    object
# dtypes: float64(3), int64(3), object(10)
# ...

# %% [markdown]
# ## how many null values present in each column?

# %%
df.isna().sum()
# Out:
# employee_id         0
# job_id              0
# manager_id          1
# department_id       0
# location_id         0
# country_id          0
# first_name          0
# last_name           0
# salary              0
# commission_pct     72
# department_name     0
# job_title           0
# city                0
# state_province      1
# country_name        0
# region_name         0
# dtype: int64

# %% [markdown]
# ## replace nan in commission_pct column to 0.0

# %%
df.commission_pct
# Out:
# 0      0.4
# 1      0.3
# 2      0.3
# 3      0.3
# 4      0.2
#       ...
# 101    NaN
# 102    NaN
# 103    NaN
# 104    NaN
# 105    NaN
# Name: commission_pct, Length: 106, dtype: float64

# %%
df.commission_pct.fillna(0.0, inplace=True)
df
# Out:
#      employee_id    job_id  manager_id  department_id  location_id country_id  \
# 0            145    SA_MAN       100.0             80         2500         UK
# 1            146    SA_MAN       100.0             80         2500         UK
# 2            147    SA_MAN       100.0             80         2500         UK
# 3            148    SA_MAN       100.0             80         2500         UK
# 4            149    SA_MAN       100.0             80         2500         UK
# ..           ...       ...         ...            ...          ...        ...
# 101          118  PU_CLERK       114.0             30         1700         US
# 102          119  PU_CLERK       114.0             30         1700         US
# 103          201    MK_MAN       100.0             20         1800         CA
# 104          202    MK_REP       201.0             20         1800         CA
# 105          200   AD_ASST       101.0             10         1700         US
#
# ...

# %% [markdown]
# ## sorting employee_id column

# %%
df.set_index('employee_id', inplace=True)
df
# Out:
#                job_id  manager_id  department_id  location_id country_id  \
# employee_id
# 145            SA_MAN       100.0             80         2500         UK
# 146            SA_MAN       100.0             80         2500         UK
# 147            SA_MAN       100.0             80         2500         UK
# 148            SA_MAN       100.0             80         2500         UK
# 149            SA_MAN       100.0             80         2500         UK
# ...               ...         ...            ...          ...        ...
# 118          PU_CLERK       114.0             30         1700         US
# 119          PU_CLERK       114.0             30         1700         US
# 201            MK_MAN       100.0             20         1800         CA
# 202            MK_REP       201.0             20         1800         CA
# 200           AD_ASST       101.0             10         1700         US
#
#             first_name   last_name   salary  commission_pct department_name  \
# ...

# %%
df.sort_index(inplace=True)
df
# Out:
#                  job_id  manager_id  department_id  location_id country_id  \
# employee_id
# 100             AD_PRES         NaN             90         1700         US
# 101               AD_VP       100.0             90         1700         US
# 102               AD_VP       100.0             90         1700         US
# 103             IT_PROG       102.0             60         1400         US
# 104             IT_PROG       103.0             60         1400         US
# ...                 ...         ...            ...          ...        ...
# 202              MK_REP       201.0             20         1800         CA
# 203              HR_REP       101.0             40         2400         UK
# 204              PR_REP       101.0             70         2700         DE
# 205              AC_MGR       101.0            110         1700         US
# 206          AC_ACCOUNT       205.0            110         1700         US
#
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#      employee_id      job_id  manager_id  department_id  location_id  \
# 0            100     AD_PRES         NaN             90         1700
# 1            101       AD_VP       100.0             90         1700
# 2            102       AD_VP       100.0             90         1700
# 3            103     IT_PROG       102.0             60         1400
# 4            104     IT_PROG       103.0             60         1400
# ..           ...         ...         ...            ...          ...
# 101          202      MK_REP       201.0             20         1800
# 102          203      HR_REP       101.0             40         2400
# 103          204      PR_REP       101.0             70         2700
# 104          205      AC_MGR       101.0            110         1700
# 105          206  AC_ACCOUNT       205.0            110         1700
#
#     country_id first_name last_name   salary  commission_pct  \
# 0           US     Steven      King  24000.0             0.0
# ...

# %% [markdown]
# ## creating one single column from first_name and last_name column as fulll_name

# %%
full_name=df['first_name'] + ' ' + df['last_name'].astype(str)
full_name
# Out:
# 0           Steven King
# 1         Neena Kochhar
# 2           Lex De Haan
# 3      Alexander Hunold
# 4           Bruce Ernst
#              ...
# 101             Pat Fay
# 102        Susan Mavris
# 103        Hermann Baer
# 104     Shelley Higgins
# 105       William Gietz
# Length: 106, dtype: object

# %%
df.insert(6, 'full_name', full_name)

# %%
df
# Out:
#      employee_id      job_id  manager_id  department_id  location_id  \
# 0            100     AD_PRES         NaN             90         1700
# 1            101       AD_VP       100.0             90         1700
# 2            102       AD_VP       100.0             90         1700
# 3            103     IT_PROG       102.0             60         1400
# 4            104     IT_PROG       103.0             60         1400
# ..           ...         ...         ...            ...          ...
# 101          202      MK_REP       201.0             20         1800
# 102          203      HR_REP       101.0             40         2400
# 103          204      PR_REP       101.0             70         2700
# 104          205      AC_MGR       101.0            110         1700
# 105          206  AC_ACCOUNT       205.0            110         1700
#
#     country_id         full_name first_name last_name   salary  \
# 0           US       Steven King     Steven      King  24000.0
# ...

# %% [markdown]
# ## removing first_name and last_name columns from dataframe

# %%
df.drop(['first_name','last_name'], axis=1, inplace=True)
df
# Out:
#      employee_id      job_id  manager_id  department_id  location_id  \
# 0            100     AD_PRES         NaN             90         1700
# 1            101       AD_VP       100.0             90         1700
# 2            102       AD_VP       100.0             90         1700
# 3            103     IT_PROG       102.0             60         1400
# 4            104     IT_PROG       103.0             60         1400
# ..           ...         ...         ...            ...          ...
# 101          202      MK_REP       201.0             20         1800
# 102          203      HR_REP       101.0             40         2400
# 103          204      PR_REP       101.0             70         2700
# 104          205      AC_MGR       101.0            110         1700
# 105          206  AC_ACCOUNT       205.0            110         1700
#
#     country_id         full_name   salary  commission_pct   department_name  \
# ...

# %% [markdown]
# ## how many unique regions are there in dataframe?

# %%
df.region_name.unique()
# Out:
# array(['Americas', 'Europe'], dtype=object)

# %% [markdown]
# ## how many unique countries are there in dataframe?

# %%
df.country_name.unique()
# Out:
# array(['United States of America', 'United Kingdom', 'Canada', 'Germany'],
#       dtype=object)

# %% [markdown]
# ## how many unique states are there in dataframe?

# %%
df.state_province.unique()
# Out:
# array(['Washington', 'Texas', 'California', 'Oxford', 'Ontario', nan,
#        'Bavaria'], dtype=object)

# %% [markdown]
# ## how many unique cities are there in dataframe?

# %%
df.city.unique()
# Out:
# array(['Seattle', 'Southlake', 'South San Francisco', 'Oxford', 'Toronto',
#        'London', 'Munich'], dtype=object)

# %% [markdown]
# ## how many unique job titles are there in dataframe?

# %%
df.job_title.unique()
# Out:
# array(['President', 'Administration Vice President', 'Programmer',
#        'Finance Manager', 'Accountant', 'Purchasing Manager',
#        'Purchasing Clerk', 'Stock Manager', 'Stock Clerk',
#        'Sales Manager', 'Sales Representative', 'Shipping Clerk',
#        'Administration Assistant', 'Marketing Manager',
#        'Marketing Representative', 'Human Resources Representative',
#        'Public Relations Representative', 'Accounting Manager',
#        'Public Accountant'], dtype=object)

# %% [markdown]
# ## how many unique departments are there in dataframe?

# %%
df.department_name.unique()
# Out:
# array(['Executive', 'IT', 'Finance', 'Purchasing', 'Shipping', 'Sales',
#        'Administration', 'Marketing', 'Human Resources',
#        'Public Relations', 'Accounting'], dtype=object)

# %% [markdown]
# ## which deparment giving highest salary?

# %%
pd.pivot_table(df, index='department_name', values='salary', aggfunc=max).sort_values(by='salary', ascending=False)
# Out:
#                    salary
# department_name
# Executive         24000.0
# Sales             14000.0
# Marketing         13000.0
# Accounting        12000.0
# Finance           12000.0
# Purchasing        11000.0
# Public Relations  10000.0
# IT                 9000.0
# Shipping           8200.0
# Human Resources    6500.0
# Administration     4400.0

# %%
x=pd.pivot_table(df, index='department_name', values='salary', aggfunc=max).sort_values(by='salary', ascending=False).index
x
# Out:
# Index(['Executive', 'Sales', 'Marketing', 'Accounting', 'Finance',
#        'Purchasing', 'Public Relations', 'IT', 'Shipping', 'Human Resources',
#        'Administration'],
#       dtype='object', name='department_name')

# %%
y=pd.pivot_table(df, index='department_name', values='salary', aggfunc=max).sort_values(by='salary', ascending=False).values
y
# Out:
# array([[24000.],
#        [14000.],
#        [13000.],
#        [12000.],
#        [12000.],
#        [11000.],
#        [10000.],
#        [ 9000.],
#        [ 8200.],
#        [ 6500.],
#        [ 4400.]])

# %%
def add_value_label(x_list,y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center')

plt.figure(figsize=(12,5))
sns.barplot(x='department_name', y='salary', data=df, estimator=max, ci=None, order=x)
plt.xticks(rotation=45)

add_value_label(x,y);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# ## which job title giving highest salary?

# %%
pd.pivot_table(df, index='job_title', values='salary', aggfunc=max).sort_values(by='salary', ascending=False)
# Out:
#                                   salary
# job_title
# President                        24000.0
# Administration Vice President    17000.0
# Sales Manager                    14000.0
# Marketing Manager                13000.0
# Finance Manager                  12000.0
# Accounting Manager               12000.0
# Sales Representative             11500.0
# Purchasing Manager               11000.0
# Public Relations Representative  10000.0
# Accountant                        9000.0
# Programmer                        9000.0
# Public Accountant                 8300.0
# Stock Manager                     8200.0
# Human Resources Representative    6500.0
# Marketing Representative          6000.0
# Administration Assistant          4400.0
# Shipping Clerk                    4200.0
# Stock Clerk                       3600.0
# Purchasing Clerk                  3100.0

# %%
x=pd.pivot_table(df, index='job_title', values='salary', aggfunc=max).sort_values(by='salary', ascending=False).index
x
# Out:
# Index(['President', 'Administration Vice President', 'Sales Manager',
#        'Marketing Manager', 'Finance Manager', 'Accounting Manager',
#        'Sales Representative', 'Purchasing Manager',
#        'Public Relations Representative', 'Accountant', 'Programmer',
#        'Public Accountant', 'Stock Manager', 'Human Resources Representative',
#        'Marketing Representative', 'Administration Assistant',
#        'Shipping Clerk', 'Stock Clerk', 'Purchasing Clerk'],
#       dtype='object', name='job_title')

# %%
y=pd.pivot_table(df, index='job_title', values='salary', aggfunc=max).sort_values(by='salary', ascending=False).values
y
# Out:
# array([[24000.],
#        [17000.],
#        [14000.],
#        [13000.],
#        [12000.],
#        [12000.],
#        [11500.],
#        [11000.],
#        [10000.],
#        [ 9000.],
#        [ 9000.],
#        [ 8300.],
#        [ 8200.],
#        [ 6500.],
#        [ 6000.],
#        [ 4400.],
#        [ 4200.],
#        [ 3600.],
#        [ 3100.]])

# %%
def add_value_label(x_list,y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center')

plt.figure(figsize=(12,5))
sns.barplot(x='job_title', y='salary', data=df, estimator=max, ci=None, order=x)
plt.xticks(rotation=45)

add_value_label(x,y);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# ## which employee getting highest salary?

# %%
x=pd.pivot_table(df, index='full_name', values='salary', aggfunc=max).sort_values(by='salary', ascending=False)[:10].index
x
# Out:
# Index(['Steven King', 'Lex De Haan', 'Neena Kochhar', 'John Russell',
#        'Karen Partners', 'Michael Hartstein', 'Alberto Errazuriz',
#        'Shelley Higgins', 'Nancy Greenberg', 'Lisa Ozer'],
#       dtype='object', name='full_name')

# %%
y=pd.pivot_table(df, index='full_name', values='salary', aggfunc=max).sort_values(by='salary', ascending=False)[:10].values
y
# Out:
# array([[24000.],
#        [17000.],
#        [17000.],
#        [14000.],
#        [13500.],
#        [13000.],
#        [12000.],
#        [12000.],
#        [12000.],
#        [11500.]])

# %%
def add_value_label(x_list,y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center')

plt.figure(figsize=(12,5))
sns.barplot(x='full_name', y='salary', data=df, estimator=max, ci=None, order=x)
plt.xticks(rotation=45)

add_value_label(x,y);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# ## in which region these top 10 salaries person living?

# %%
def add_value_label(x_list,y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center')

plt.figure(figsize=(12,5))
sns.barplot(x='full_name', y='salary', data=df, estimator=max, ci=None,
            hue='region_name', order=x)
plt.xticks(rotation=45)

add_value_label(x,y);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# ## in which country these top 10 salaries person living?

# %%
def add_value_label(x_list,y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center')

plt.figure(figsize=(12,5))
sns.barplot(x='full_name', y='salary', data=df, estimator=max, ci=None, 
            hue='country_name', order=x)
plt.xticks(rotation=45)

add_value_label(x,y);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# ## in which states these top 10 earning people living?

# %%
def add_value_label(x_list,y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center')

plt.figure(figsize=(12,5))
sns.barplot(x='full_name', y='salary', data=df, estimator=max, ci=None, 
            hue='state_province', order=x)
plt.xticks(rotation=45)

add_value_label(x,y);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# ## in which cities these top 10 earning people living?

# %%
def add_value_label(x_list,y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center')

plt.figure(figsize=(12,5))
sns.barplot(x='full_name', y='salary', data=df, estimator=max, ci=None, 
            hue='city', order=x)
plt.xticks(rotation=45)

add_value_label(x,y);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# ## how many employees working for each department?

# %%
plt.figure(figsize=(12,6))
ax=sns.countplot(x='department_name', data=df,
            order=df.department_name.value_counts(ascending=False).index)
plt.xticks(rotation=45)

labels = df.department_name.value_counts(ascending=False).values

ax.bar_label(container=ax.containers[0], labels=labels);

# %% [markdown]
# ## how many employees working with different job title?

# %%
plt.figure(figsize=(12,6))
ax=sns.countplot(x='job_title', data=df,
            order=df.job_title.value_counts(ascending=False).index)
plt.xticks(rotation=90)

labels = df.job_title.value_counts(ascending=False).values

ax.bar_label(container=ax.containers[0], labels=labels);
